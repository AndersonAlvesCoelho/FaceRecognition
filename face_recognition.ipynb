# %%
# !pip install deepface numpy scipy tensorflow tf-keras matplotlib opencv-python
# !pip install --upgrade pip

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2

# %%
img1_path = "./img/beyonce-2.jpg"
img2_path = "./img/beyonce-1.jpg"

# %%
result = DeepFace.verify(
  img1_path = img1_path,
  img2_path = img2_path,
  model_name="VGG-Face",  
  detector_backend="opencv", 
  enforce_detection=False  
)

# %%
img1 = cv2.imread(img1_path)
img2 = cv2.imread(img2_path)

img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(img1)
axes[0].set_title("Imagem 1")
axes[0].axis("off") 

axes[1].imshow(img2)
axes[1].set_title("Imagem 2")
axes[1].axis("off")

plt.show()

print("\nResultado da Verificação Facial:")
print("=" * 30)
print(f"Imagens comparadas: {img1_path} e {img2_path}")
print(f"São a mesma pessoa? {'Sim' if result['verified'] else 'Não'}")
print(f"Similaridade: {result['distance']:.4f}")
print("=" * 30)
# Out:
# Resultado da Verificação Facial:
# ==============================
# Imagens comparadas: ./img/beyonce-2.jpg e ./img/beyonce-1.jpg
# São a mesma pessoa? Sim
# Similaridade: 0.5516
# ==============================
